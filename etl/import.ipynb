# %%
# import requests
# import pandas as pd

# URL = "https://excel-dbpostgresql-api.onrender.com/personnes"

# response = requests.get(URL)

# data = response.json()

# df = pd.DataFrame(data)

# print(df.head())
